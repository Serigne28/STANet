# %% [markdown]
# <a href="https://colab.research.google.com/github/Serigne28/STANet/blob/master/stanet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Serigne28/STANet
# Out:
# Cloning into 'STANet'...
# remote: Enumerating objects: 126, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 126 (delta 39), reused 106 (delta 25), pack-reused 0
# Receiving objects: 100% (126/126), 1.93 MiB | 34.07 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
# !cd /content/STANet

# %%
# !python /content/STANet/demo.py
# Out:
# ----------------- Options ---------------
#                   SA_mode: BAM
#                     angle: 0
#                      arch: mynet3
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./LEVIR-CD
#              dataset_mode: changedetection
#              dataset_type: CD_LEVIR
#           display_winsize: 256
#                        ds: 1                             	[default: 1]
#                     epoch: latest
#                      eval: False
#                       f_c: 64
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                    istest: False
#                 json_name: train_val_test
#                 load_iter: 0                             	[default: 0]
# ...

# %%
# !pip install visdom
# Out:
# ...
#      |████████████████████████████████| 676 kB 8.4 MB/s
# ...
#      |████████████████████████████████| 68 kB 8.7 MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655249 sha256=e68add096409c62bbe4666004e4f9ac7af566c4425015b9729e69228a8eb8a9b
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5710 sha256=9e55f4a0ae7650118b907ae5f03f57f5805926ec42512ad4410b0fcf6fb8b49e
#   Stored in directory: /root/.cache/pip/wheels/ac/5c/3a/a80e1c65880945c71fd833408cd1e9a8cb7e2f8f37620bb75b
# Successfully built visdom torchfile
# ...

# %%
# !python -m visdom.server
# Out:
# /usr/local/lib/python3.7/dist-packages/visdom/server.py:39: DeprecationWarning: zmq.eventloop.ioloop is deprecated in pyzmq 17. pyzmq now works with default tornado and asyncio eventloops.
#   ioloop.install()  # Needs to happen before any tornado imports!
# Checking for scripts.
# ...
# It's Alive!
# INFO:root:Application Started
# You can navigate to http://1105efa765ec:8097
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.7/dist-packages/visdom/server.py", line 1922, in <module>
#     download_scripts_and_run()
#   File "/usr/local/lib/python3.7/dist-packages/visdom/server.py", line 1918, in download_scripts_and_run
#     main()
#   File "/usr/local/lib/python3.7/dist-packages/visdom/server.py", line 1913, in main
# ...

# %%
pip install dominate

# %% [markdown]
# **Entraînement du modèle**

# %%
# !python /content/STANet/train.py --save_epoch_freq 1 --angle 15 --dataroot /content/drive/MyDrive/LEVIR-CD --name LEVIR-CDF0 --lr 0.001 --model CDF0 --batch_size 8 --load_size 128 --crop_size 256 --preprocess rotate_and_crop --display_id 0 --dataroot /content/drive/MyDrive/LEVIR-CD --val_dataroot /content/drive/MyDrive/LEVIR-CD --checkpoints_dir /content/drive/MyDrive/verbose13352407 --continue_train --epoch_count 153
# Out:
# ----------------- Options ---------------
#                   SA_mode: BAM
#                     angle: 15                            	[default: 0]
#                      arch: mynet3
#                batch_size: 8                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /content/drive/MyDrive/verbose13352407	[default: ./checkpoints]
#            continue_train: True                          	[default: False]
#                 crop_size: 256
#                  dataroot: /content/drive/MyDrive/LEVIR-CD	[default: ./LEVIR-CD]
#              dataset_mode: changedetection
#              dataset_type: CD_LEVIR
#               display_env: main
#              display_freq: 400
#                display_id: 0                             	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
# ...

# %% [markdown]
# **Inférences**

# %%
# !python /content/STANet/val.py --dataroot /content/drive/MyDrive/LEVIR-CD --val_dataroot /content/drive/MyDrive/LEVIR-CD --checkpoints_dir /content/drive/MyDrive/verbose13352407
# Out:
# ----------------- Options ---------------
#                   SA_mode: BAM
#                     angle: 0
#                      arch: mynet3
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /content/drive/MyDrive/verbose13352407	[default: ./checkpoints]
#                 crop_size: 256
#                  dataroot: /content/drive/MyDrive/LEVIR-CD	[default: ./LEVIR-CD]
#              dataset_mode: changedetection
#              dataset_type: CD_LEVIR
#           display_winsize: 256
#                        ds: 1                             	[default: 1]
#                     epoch: latest
#                      eval: False
#                       f_c: 64
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                    istest: False
#                 json_name: train_val_test
# ...

# %% [markdown]
# **Test sur un autre dataset (second_dataset)**

# %%
# !python /content/STANet/val.py --dataroot /content/drive/MyDrive/second_dataset --results_dir /content/drive/MyDrive/resultats/ --checkpoints_dir /content/drive/MyDrive/resultats/
# Out:
# ----------------- Options ---------------
#                   SA_mode: BAM
#                     angle: 0
#                      arch: mynet3
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /content/drive/MyDrive/resultats/	[default: ./checkpoints]
#                 crop_size: 256
#                  dataroot: /content/drive/MyDrive/second_dataset	[default: ./LEVIR-CD]
#              dataset_mode: changedetection
#              dataset_type: CD_LEVIR
#           display_winsize: 256
#                        ds: 1                             	[default: 1]
#                     epoch: latest
#                      eval: False
#                       f_c: 64
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                    istest: False
#                 json_name: train_val_test
# ...
